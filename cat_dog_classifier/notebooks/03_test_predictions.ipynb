# %% [markdown]
# # Test Predictions
#
# This notebook is used to load a trained model and test predictions on new images.

# %%
from pathlib import Path

project_root = Path.cwd().resolve()
print(project_root)
